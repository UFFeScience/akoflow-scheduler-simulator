# %% [markdown]
# # Validação dos dados experimentais
#
# Este notebook verifica quantidade de execuções, pareamento das sementes, seleção das 29 atividades e constância do budget e deadline.

# %%
from pathlib import Path
import sys
repo_root = Path('/workspace')
sys.path.insert(0, str(repo_root / 'experiments/notebooks'))
from plot_experiments import load_results, validate_results

df, manifest = load_results(repo_root)
counts = validate_results(df, manifest)
counts
# Out:
#        scenario_id  algorithm  runs
# 0     cloud_hetero  beam_cost    30
# 1     cloud_hetero  beam_time    30
# 2     cloud_hetero       heft    30
# 3       cloud_homo  beam_cost    30
# 4       cloud_homo  beam_time    30
# 5       cloud_homo       heft    30
# 6   cluster_hetero  beam_cost    30
# 7   cluster_hetero  beam_time    30
# 8   cluster_hetero       heft    30
# 9     cluster_homo  beam_cost    30
# 10    cluster_homo  beam_time    30
# 11    cluster_homo       heft    30
# 12   hybrid_hetero  beam_cost    30
# 13   hybrid_hetero  beam_time    30
# 14   hybrid_hetero       heft    30
# 15     hybrid_homo  beam_cost    30
# 16     hybrid_homo  beam_time    30
# 17     hybrid_homo       heft    30

# %%
validation = {
    'execucoes': len(df),
    'sementes': df['interference_seed'].nunique(),
    'atividades_por_execucao': 29,
    'budget_global_media_heft': df['budget_limit'].iloc[0],
    'deadline_global_media_heft': df['deadline_limit'].iloc[0],
}
validation
# Out:
# {'execucoes': 540,
#  'sementes': 30,
#  'atividades_por_execucao': 29,
#  'budget_global_media_heft': np.float64(0.503637),
#  'deadline_global_media_heft': np.float64(170.72955)}
