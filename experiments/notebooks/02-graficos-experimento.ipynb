# %% [markdown]
# # Geração dos gráficos experimentais
#
# Gera os 12 gráficos do protocolo e um relatório Markdown com a descrição de cada figura.

# %%
from pathlib import Path
import sys
repo_root = Path('/workspace')
sys.path.insert(0, str(repo_root / 'experiments/notebooks'))
from plot_experiments import generate_all

figures = generate_all(repo_root)
print(f'{len(figures)} gráficos gerados em experiments/results/figures')
for figure in figures:
    print(figure.name)
# Out:
# /workspace/experiments/notebooks/plot_experiments.py:114: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER])
# /workspace/experiments/notebooks/plot_experiments.py:130: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER])
# /workspace/experiments/notebooks/plot_experiments.py:148: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER])
# /workspace/experiments/notebooks/plot_experiments.py:202: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER], rotation=15)
# /workspace/experiments/notebooks/plot_experiments.py:202: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER], rotation=15)
# /workspace/experiments/notebooks/plot_experiments.py:235: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER])
# /workspace/experiments/notebooks/plot_experiments.py:314: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER])
# 12 gráficos gerados em experiments/results/figures
# 01-makespan-por-ambiente.png
# 02-custo-por-ambiente.png
# 03-factibilidade.png
# 04-custo-versus-makespan.png
# 05-ganho-beam-sobre-heft.png
# 06-interferencia-versus-makespan.png
# 07-pares-versus-makespan.png
# 08-tempo-de-interferencia.png
# 09-heatmap-utilizacao.png
# 10-distribuicao-atividades.png
# 11-tempo-computacional.png
# 12-estabilidade-por-semente.png

# %% [markdown]
# As descrições e imagens estão reunidas em `experiments/results/figures/README.md`.
