# %% [markdown]
# # Geração dos gráficos experimentais
#
# Gera os 12 gráficos do protocolo e um relatório Markdown com a descrição de cada figura.

# %%
from pathlib import Path
import sys
repo_root = Path('/workspace')
sys.path.insert(0, str(repo_root / 'experiments/notebooks'))
from plot_experiments import generate_all

figures = generate_all(repo_root)
print(f'{len(figures)} gráficos gerados em experiments/results/figures')
for figure in figures:
    print(figure.name)
# Out:
# /workspace/experiments/notebooks/plot_experiments.py:127: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER])
# /workspace/experiments/notebooks/plot_experiments.py:143: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER])
# /workspace/experiments/notebooks/plot_experiments.py:161: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([SCENARIO_LABELS[item] for item in SCENARIO_ORDER])
# /workspace/experiments/notebooks/plot_experiments.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %% [markdown]
# As descrições e imagens estão reunidas em `experiments/results/figures/README.md`.
